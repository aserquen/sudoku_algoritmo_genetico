# %% [markdown]
# # Optimizacion Industrial con Computacion Evolutiva
# <b> Diplomatura de Especialización en Desarrollo de Aplicaciones con Inteligencia Artificial</b>
#
# * Antony Marin,
# * Oscar Serquén
# * Christian Solano

# %% [markdown]
# ## DESAFIO: Algoritmo Genetico para resolver el tablero de Sudoku
#
# Sudoku es un juego de lógica japonés en donde el objetivo es rellenar una celda de 9×9 casillas con números del 1 al 9, de manera que cada columna, fila y cada uno de las subceldas 3×3 que componen la celda 9×9 contengan cada número solo una vez.
#
# Este trabajo pretende solucionar tableros de Sudoku un juego ampliamente conocido, con el fin de poner en práctica los conceptos de un algoritmo genético tales como: población, individuo, cromosoma, fitness, selección, cruzamiento, mutación, generación entre otros.

# %%
import sys
import time
#import random
from random import shuffle, random, sample, randint , uniform , randrange
import numpy as np
from copy import deepcopy
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import heapq
import math

# %%
class Individual(object):   
   
    def __init__(self, chromosome):
            self.chromosome = chromosome[:]
            self.fitness = -1  # -1 indica que el individuo no ha sido evaluado
     
    def crossover_onepoint(self, other):
        "Retorna dos nuevos individuos del cruzamiento de un punto entre individuos self y other "
        c = randrange(len(self.chromosome))
        ind1 = Individual(self.chromosome[:c] + other.chromosome[c:])
        ind2 = Individual(other.chromosome[:c] + self.chromosome[c:])
        return [ind1, ind2]   
    
    def crossover_uniform(self, other):
        chromosome1 = []
        chromosome2 = []
        "Retorna dos nuevos individuos del cruzamiento uniforme entre self y other"
        for i in range(len(self.chromosome)):
            if uniform(0, 1) < 0.5:
                chromosome1.append(self.chromosome[i])
                chromosome2.append(other.chromosome[i])
            else:
                chromosome1.append(other.chromosome[i])
                chromosome2.append(self.chromosome[i])
        ind1 = Individual(chromosome1)
        ind2 = Individual(chromosome2)
        return [ind1, ind2]     
    
    def crossover_orderpermutation(self, other):
        "Uniform order-based crossover. Genera 2 cromosomas hijos  que tambien deben ser permutaciones" 
        "Retorna dos nuevos individuos del cruzamiento de permutacion entre self y other" 
        "Escoge aleatoriamente la mitad de posiciones del cromosoma self y lo copia a un hijo ind1 en las mismas posiciones" 
        "Los numeros faltantes los copia de other en el mismo orden en que aparecen en other "
        "El hijo ind2 se crea de la misma forma intercambiando self por other"
        
        
        pos_constantes = []
        pos_constantes = sample(range(len(self.chromosome)),len(self.chromosome)//2)
        cromosomo1 = [-1]*len(self.chromosome) 
        cromosomo2 = [-1]*len(self.chromosome) 
        
        for index in pos_constantes:
            cromosomo1[index]= self.chromosome[index]
            cromosomo2[index] = other.chromosome[index]
            
        
        for i in range(len(self.chromosome)):
            if(cromosomo1[i] == -1):
                for j in range(len(other.chromosome)):
                    if other.chromosome[j] not in cromosomo1:
                        cromosomo1[i] = other.chromosome[j]
                        break
                        
                for j in range(len(self.chromosome)):
                    if self.chromosome[j] not in cromosomo2:
                        cromosomo2[i] = self.chromosome[j]
                        break          
        
        ind1 = Individual(cromosomo1)
        ind2 = Individual(cromosomo2)
        return [ind1, ind2]          
    
    
    def mutate_position(self): 
        """       mutate_position
        Cambia aleatoriamente un alelo de un gen."""
        mutated_chromosome = deepcopy(self.chromosome)
        mutGene = randrange(1,len(mutated_chromosome)) 
        newAllele = randrange(1,9)
        mutated_chromosome[mutGene] = newAllele
        return Individual(mutated_chromosome)    
        
    def mutate_swap(self):
        "Escoge dos genes e intercambia sus alelos"
        mutated_chromosome = deepcopy(self.chromosome[:])
        mutGen1 = randrange(1,len(mutated_chromosome))
        mutGen2 = randrange(1,len(mutated_chromosome))
        temp = mutated_chromosome[mutGen1]
        mutated_chromosome[mutGen1] = mutated_chromosome[mutGen2]
        mutated_chromosome[mutGen2] = temp
        return Individual(mutated_chromosome)

    def mutate_make_neighborBoard(self):
        " Genera un tablero nuevo. Se escoje aleatoriamente un bloque y se intercambia dos valores (no dados en el tablero original)"
        mutated_chromosome = deepcopy(self.chromosome)
        initialEntries = np.arange(81)[np.array(mutated_chromosome) > 0]
        block = randint(0,8)  # escoje un bloque aleatoriamente
        num_in_block = len(get_block_indices(block,initialEntries,ignore_originals=True)) #cantidad de posiciones que se puede alterar en el bloque
        if  num_in_block>1 :
          random_squares = sample(range(num_in_block),2) # escoje dos posiciones aleatorias del bloque para intercambiar valores
          square1, square2 = [get_block_indices(block,initialEntries,ignore_originals=True)[ind] for ind in random_squares]
          mutated_chromosome[square1], mutated_chromosome[square2] = mutated_chromosome[square2], mutated_chromosome[square1] # intercambia los valores de las posiciones
        else:mutated_chromosome
        return Individual(mutated_chromosome)

# %% [markdown]
# ### Funciones para inicializar y visualizar Poblaciones

# %%
def readBoardFromFile(filename):
    fd = open(filename,"r+")    
    puzzle = eval(fd.readline())
    board = []
    for row in puzzle:
        for col in row:
            board.append(col)
    return board  #  el tablero es un vector con las filas concatenadas
  
#readBoardFromFile('/content/puzzleA.txt')

# %%
def init_population(pop_number, size_chromosoma):
    population = []
    state_length=2
    ## Crea la poblacion inicial con cromosomas aleatorios (permutaciones)
    for i in range(pop_number):
        new_chromosome = [randint(0,9) for j in range(0,size_chromosoma)]
        #shuffle(new_chromosome)
        population.append(Individual(new_chromosome))
    return population

# %% [markdown]
# Estas son funciones utilitarias para trabajar con tableros de sudoku

# %%
# devuelve los indices de los elementos de la columna i del tablero  
def get_column_indices(i):  
    indices = [i + 9 * j for j in range(9)]
    return indices

# devuelve los indices de los elementos de la fila i del tablero 
def get_row_indices(i):  
    indices = [j + 9*i for j in range(9)]
    return indices

# devuelve los indices de los elementos del bloque k del tablero. initialEntries son los indices de las posiciones inmutables (numeros iniciales) 
# si ignore_originals=true  entonces solo devuelve los indices de las posiciones que no son las posiciones inmutables
def get_block_indices(k, initialEntries, ignore_originals=False): 
    row_offset = (k//3)*3
    col_offset= (k%3)*3
    indices=[col_offset+(j%3)+9*(row_offset+(j//3)) for j in range(9)]
    if ignore_originals:
        indices = [x for x in indices if x not in initialEntries]
    return indices

# Completa aleatoriamente las pociciones vacias (que no son initialEntries). 
# Garantiza que en cada bloque se generen 9 numeros diferentes 
def randomAssign(board, initialEntries):
    for num in range(9):
        block_indices = get_block_indices(num, initialEntries)
        block = board[block_indices]
        zero_indices=[ind for i,ind in enumerate(block_indices) if block[i] == 0]
        to_fill = [i for i in range(1,10) if i not in block]
        shuffle(to_fill)
        for ind, value in zip(zero_indices, to_fill):
            board[ind] = value
    return board

def showBoard(board):
    board=np.array(board)
    def checkZero(s):
        if s != 0: return str(s)
        if s == 0: return "0"
    results = np.array([board[get_row_indices(j)] for j in range(9)])
    s=""
    for i, row in enumerate(results):
        if i%3==0:
            s +="-"*25+'\n'
        s += "| " + " | ".join([" ".join(checkZero(s) for s in list(row)[3*(k-1):3*k]) for k in range(1,4)]) + " |\n"
    s +="-"*25+''
    print (s)

# %% [markdown]
# Funcion para mostrar una población y su fitnes

# %%
def display_population(population):
    listaAG=[]
    for i in range(len(population)):
        listaAG.append([population[i].chromosome,population[i].fitness])

    data=pd.DataFrame(listaAG)
    data.columns = ['Poblacion','fitness']
    return data

# %% [markdown]
# ### Funcion de Fitness

# %% [markdown]
# Funcion para evaluar el fitness de un Cromosoma (tablero de n-reinas):  nro de pares de reinas no atacadas (maximo valor = n*(n-1)/2)

# %%
# Evalua un tablero. Devuelve la cantidad de numeros diferentes en todas las filas y columnas 
# un tablero solucion tiene un score de 162 (81+81)
def fitness_soduko(chromosome):
    chromosome=np.array(chromosome)
    """Retorna el fitness de un cromosoma en el problema"""
    fitness = 0
    for row in range(9): # por cada fila obtiene la cantidad de numeros diferentes
        fitness+= len(set(chromosome[get_row_indices(row)]))
    for col in range(9): # por cada columna obtiene la cantidad de numeros diferentes
        fitness += len(set(chromosome[get_column_indices(col)]))
    return fitness

# %% [markdown]
# Funcion para evaluar toda una población de individuos con la funcion de fitnes especificada

# %%
def evaluate_population(population, fitness_soduko):
    """ Evalua una poblacion de individuos con la funcion de fitness pasada """
    for i in range(len(population)):
        if population[i].fitness == -1:    # si el individuo no esta evaluado
            population[i].fitness = fitness_soduko(population[i].chromosome)
    return population

# %% [markdown]
# ### Operadores de seleccion de padres

# %% [markdown]
# #### Seleccion por Ruleta

# %%
def select_parents_roulette(population):
    popsize = len(population)
    
    # Escoje el primer padre
    sumfitness = sum([indiv.fitness for indiv in population])  # suma total del fitness de la poblacion
    pickfitness = uniform(0, sumfitness)   # escoge un numero aleatorio entre 0 y sumfitness
    cumfitness = 0     # fitness acumulado
    for i in range(popsize):
        cumfitness += population[i].fitness
        if cumfitness > pickfitness: 
            iParent1 = i
            break
     
    # Escoje el segundo padre, desconsiderando el primer padre
    sumfitness = sumfitness - population[iParent1].fitness # retira el fitness del padre ya escogido
    pickfitness = uniform(0, sumfitness)   # escoge un numero aleatorio entre 0 y sumfitness
    cumfitness = 0     # fitness acumulado
    for i in range(popsize):
        if i == iParent1: continue   # si es el primer padre 
        cumfitness += population[i].fitness
        if cumfitness > pickfitness: 
            iParent2 = i
            break        
    return (population[iParent1], population[iParent2])

# %% [markdown]
# #### Seleccion por Torneo

# %%
def select_parents_torneo(population,size_torneo):
    
    # Escoje el primer padre
    list_indiv=[]
    x1 = np.random.permutation(len(population) )
    y1= x1[0:size_torneo]
    for i in range(size_torneo):
        list_indiv.append(population[y1[i]].fitness)
    
    iParent1=np.argmax(list_indiv)
    
    # Escoje el segundo padre, desconsiderando el primer padre   
    x2 = np.delete(x1, iParent1)
    x2 = np.random.permutation(x2)
    list_indiv=[]
    y2= x2[0:size_torneo]
    for i in range(size_torneo):
        list_indiv.append(population[y2[i]].fitness)
    iParent2=np.argmax(list_indiv)
    
    return (population[x1[iParent1]],population[x2[iParent2]])

# %% [markdown]
# ## Seleccion de sobrevivientes por Ranking

# %% [markdown]
# #### Seleccion de sobrevivientes por ranking

# %%
def select_survivors_ranking(population, offspring_population, numsurvivors):
    next_population = []
    population.extend(offspring_population) # une las dos poblaciones
    isurvivors = sorted(range(len(population)), key=lambda i: population[i].fitness, reverse=True)[:numsurvivors]
    for i in range(numsurvivors): next_population.append(population[isurvivors[i]])
    return next_population

# %% [markdown]
# ## Algoritmo Genetico
# Recibe una poblacion inicial, funcion de fitness, numero de generaciones (ngen), metodoSeleccion (ruleta/torneo), tournament_size, taza de mutación (pmut), operador de cruzamiento (crossover) y operador de mutacion (mutation)

# %%
def genetic_algorithm(poblacion_inicial, fitness_fn, ngen=100, pmut=0.1, tournament_size=3,
                      crossover="onepoint", mutation="flip", 
                      selection_parents_method="roulette", 
                      selection_survivors_method="ranking"):
    """Algoritmo Genetico para el problema de la mochila
        ngen:       maximo numero de generaciones 
        pmut:       tasa de mutacion
        crossover:  operador de cruzamiento
        mutation:   operador de mutacion
        selection_parents_method: método de selección de padres para cruzamiento
        selection_survivors_method: método de selección de sobrevivientes 
    """
    population = deepcopy(poblacion_inicial)  # copia la poblacion inicial en una nueva variable para no alterar la inicial
    
    popsize = len(population)
    
    # Evalua la poblacion inicial
    evaluate_population(population, fitness_fn)  
    
    ibest = sorted(range(len(population)), key=lambda i: population[i].fitness, reverse=True)[:1]
    bestfitness = [population[ibest[0]].fitness]
    print("Poblacion inicial, best_fitness = {}".format(population[ibest[0]].fitness))
    
    # reemplaza los valores Nulos o 0 de los cromosomas por un valor del 1 al 9
    for i in range(len(population)):
      crom=np.array(population[i].chromosome)
      initialEntries = np.arange(81)[crom > 0]
      population[i].chromosome=randomAssign(crom, initialEntries).tolist()

    for g in range(ngen):   # Por cada generacion
        
        ## Selecciona las parejas de padres (mating pool) para cruzamiento 
        mating_pool = []
        if selection_parents_method=="roulette":
            for i in range(int(popsize/2)): mating_pool.append(select_parents_roulette(population)) 
        elif selection_parents_method=="tournament" :
            for i in range(int(popsize/2)): mating_pool.append(select_parents_torneo(population,tournament_size))
        else:
            raise NotImplementedError
                
        ## Crea la poblacion descendencia cruzando las parejas del mating pool 
        offspring_population = []
        for i in range(len(mating_pool)): 
            if crossover == "onepoint":# cruzamiento 1 punto
                offspring_population.extend( mating_pool[i][0].crossover_onepoint(mating_pool[i][1]) ) 
            elif crossover == "uniform":# cruzamiento uniforme
                offspring_population.extend( mating_pool[i][0].crossover_uniform(mating_pool[i][1]) ) 
            elif crossover == "orderpermutation":# cruzamiento uniforme
                offspring_population.extend( mating_pool[i][0].crossover_orderpermutation(mating_pool[i][1]) ) 
            else:
                raise NotImplementedError                
           
        ## Aplica el operador de mutacion con probabilidad pmut en cada hijo generado
        for i in range(len(offspring_population)):
            if uniform(0, 1) < pmut: 
                if mutation == "position":
                    offspring_population[i] = offspring_population[i].mutate_position()   # mutacion de una posicion
                elif mutation == "swap":
                    offspring_population[i] = offspring_population[i].mutate_swap()      # mutacion swap
                elif mutation == "neighborBoard":
                    offspring_population[i] = offspring_population[i].mutate_make_neighborBoard()      # mutacion make neighborBoard
                else:
                    raise NotImplementedError
        
        ## Evalua la poblacion descendencia creada
        evaluate_population(offspring_population, fitness_fn)  
        
        ## Selecciona popsize individuos para la sgte. generación 
        if selection_survivors_method == "ranking":
            population = select_survivors_ranking(population, offspring_population, popsize) #metodo de ranking
        else:
            raise NotImplementedError        
  
        ## Almacena la historia del fitness del mejor individuo
        ibest = sorted(range(len(population)), key=lambda i: population[i].fitness, reverse=True)[:1]
        bestfitness.append(population[ibest[0]].fitness)
        print("generacion {}, best_fitness = {},best_cromosoma = {}".format(g, population[ibest[0]].fitness,population[ibest[0]].chromosome))
    
    return population[ibest[0]], bestfitness,population[ibest[0]].chromosome

# %% [markdown]
# ## Probando el Algoritmo genetico

# %%
## Crea la poblacion inicial con cromosomas aleatorios
size_chromosoma = 81    
num_individuals = 10

# Inicializa una poblacion inicial de forma aleatoria
poblacion_inicial = init_population(num_individuals,size_chromosoma)

# %% [markdown]
# Llama al algoritmo genetico para encontrar una solucion al problema de las n reinas

# %%
import matplotlib.pyplot as plt
ngen = 1000 # Nro de generaciones
pmut = 1 # taza de mutación
fitness_fn=fitness_soduko

metodoSeleccion=['roulette','tournament']
tournament_size = 3 #tamaño del torneo = 3

crossover=['onepoint','uniform']
mutation=['position','swap','neighborBoard']

lst_bestcrom=[]
best_ind, bestfitness,best_chromosoma = genetic_algorithm(poblacion_inicial, fitness_fn, ngen, pmut, tournament_size, 
                                          crossover[1], mutation[1], metodoSeleccion[1])
lst_bestcrom.append(best_ind)
plt.plot(bestfitness)
plt.xlabel('Generacion')
plt.ylabel('Fitness')
plt.show()
print("* Merjor Resultado *")
print("Generacion : {} , max de fitness: {} ,  Cromosoma: {} \n".format(bestfitness.index(max(bestfitness)),np.max(bestfitness),best_chromosoma))

# %%
# Grafica del tablero de soduko con la mejor solucion
showBoard(best_chromosoma)
# Out:
# -------------------------
# | 3 5 8 | 4 6 2 | 7 9 1 |
# | 4 1 5 | 3 2 8 | 6 7 9 |
# | 7 8 3 | 5 1 9 | 4 6 5 |
# -------------------------
# | 1 7 9 | 6 5 3 | 2 8 4 |
# | 8 4 7 | 2 9 5 | 1 3 6 |
# | 6 3 4 | 9 7 1 | 8 5 2 |
# -------------------------
# | 5 1 2 | 8 3 6 | 9 4 8 |
# | 8 9 6 | 1 4 7 | 5 2 3 |
# | 9 6 1 | 5 8 4 | 3 1 7 |
# -------------------------

# %%
import matplotlib.pyplot as plt
## Crea la poblacion inicial con cromosomas aleatorios
size_chromosoma = 81    
num_individuals = 10

# Inicializa una poblacion inicial de forma aleatoria
poblacion_inicial = init_population(num_individuals,size_chromosoma)

ngen = 1000 # Nro de generaciones
pmut = {0.00,0.25,0.50,0.75,1.00} # taza de mutación
fitness_fn=fitness_soduko

metodoSeleccion=['roulette','tournament']
tournament_size = 3 #tamaño del torneo = 3

crossover=['onepoint','uniform']
mutation=['position','swap','neighborBoard']

Table_Resumen=[]
for m in metodoSeleccion:
  for j in crossover:
    for i in mutation:
      for l in pmut:
        lst_bestcrom = []
        print("******** Met_Seleccion : {}   ,  crossover : {}   ,  mutation : {}   ,    pmut : {}********".format(m,j,i,l))
        for a in range(10):
          print("\nIteracion {}".format(a+1))
          lst_bestcrom=[]
          best_ind, bestfitness,best_chromosoma = genetic_algorithm(poblacion_inicial, fitness_fn, ngen, l, tournament_size,
                                                    j, i,m)
          lst_bestcrom.append(best_ind)
          plt.plot(bestfitness)
          plt.show()
          print("* Merjor Resultado *")
          print("Generacion : {} , max de fitness: {} ,  Cromosoma: {} \n".format(bestfitness.index(max(bestfitness)),np.max(bestfitness),best_chromosoma))
          Table_Resumen.append((m,j,i,l,a, bestfitness.index(max(bestfitness)),np.max(bestfitness),best_chromosoma))

# %%
import pandas as pd

resultados =pd.DataFrame(Table_Resumen)
resultados.columns=['Metodo Seleccion','Cruzamiento','Mutacion','Pm','Corrida','Generacion_Convergencia','Maximo_fitness','Cromosoma']
resultados
# Out:
#     Metodo Seleccion Cruzamiento       Mutacion    Pm  Corrida  \
# 0           roulette    onepoint       position  0.00        0
# 1           roulette    onepoint       position  0.00        1
# 2           roulette    onepoint       position  0.00        2
# 3           roulette    onepoint       position  0.00        3
# 4           roulette    onepoint       position  0.00        4
# 5           roulette    onepoint       position  0.00        5
# 6           roulette    onepoint       position  0.00        6
# 7           roulette    onepoint       position  0.00        7
# 8           roulette    onepoint       position  0.00        8
# 9           roulette    onepoint       position  0.00        9
# 10          roulette    onepoint       position  0.25        0
# 11          roulette    onepoint       position  0.25        1
# 12          roulette    onepoint       position  0.25        2
# 13          roulette    onepoint       position  0.25        3
# 14          roulette    onepoint       position  0.25        4
# 15          roulette    onepoint       position  0.25        5
# 16          roulette    onepoint       position  0.25        6
# 17          roulette    onepoint       position  0.25        7
# 18          roulette    onepoint       position  0.25        8
# 19          roulette    onepoint       position  0.25        9
# 20          roulette    onepoint       position  0.75        0
# 21          roulette    onepoint       position  0.75        1
# 22          roulette    onepoint       position  0.75        2
# 23          roulette    onepoint       position  0.75        3
# 24          roulette    onepoint       position  0.75        4
# 25          roulette    onepoint       position  0.75        5
# 26          roulette    onepoint       position  0.75        6
# 27          roulette    onepoint       position  0.75        7
# 28          roulette    onepoint       position  0.75        8
# 29          roulette    onepoint       position  0.75        9
# 30          roulette    onepoint       position  1.00        0
# 31          roulette    onepoint       position  1.00        1
# 32          roulette    onepoint       position  1.00        2
# 33          roulette    onepoint       position  1.00        3
# 34          roulette    onepoint       position  1.00        4
# 104         roulette    onepoint  neighborBoard  0.00        4
# 105         roulette    onepoint  neighborBoard  0.00        5
# 106         roulette    onepoint  neighborBoard  0.00        6
# 107         roulette    onepoint  neighborBoard  0.00        7
# 108         roulette    onepoint  neighborBoard  0.00        8
# 109         roulette    onepoint  neighborBoard  0.00        9
# 110         roulette    onepoint  neighborBoard  0.25        0
# 111         roulette    onepoint  neighborBoard  0.25        1
# 112         roulette    onepoint  neighborBoard  0.25        2
# 113         roulette    onepoint  neighborBoard  0.25        3
# 114         roulette    onepoint  neighborBoard  0.25        4
# 115         roulette    onepoint  neighborBoard  0.25        5
# 116         roulette    onepoint  neighborBoard  0.25        6
# 117         roulette    onepoint  neighborBoard  0.25        7
# 118         roulette    onepoint  neighborBoard  0.25        8
# 119         roulette    onepoint  neighborBoard  0.25        9
# 120         roulette    onepoint  neighborBoard  0.75        0
# 121         roulette    onepoint  neighborBoard  0.75        1
# 122         roulette    onepoint  neighborBoard  0.75        2
# 123         roulette    onepoint  neighborBoard  0.75        3
# 124         roulette    onepoint  neighborBoard  0.75        4
# 125         roulette    onepoint  neighborBoard  0.75        5
# 126         roulette    onepoint  neighborBoard  0.75        6
# 127         roulette    onepoint  neighborBoard  0.75        7
# 128         roulette    onepoint  neighborBoard  0.75        8
# 129         roulette    onepoint  neighborBoard  0.75        9
# 130         roulette    onepoint  neighborBoard  1.00        0
# 131         roulette    onepoint  neighborBoard  1.00        1
# 132         roulette    onepoint  neighborBoard  1.00        2
# 133         roulette    onepoint  neighborBoard  1.00        3
# 134         roulette    onepoint  neighborBoard  1.00        4
# 135         roulette    onepoint  neighborBoard  1.00        5
# 136         roulette    onepoint  neighborBoard  1.00        6
# 137         roulette    onepoint  neighborBoard  1.00        7
# 138         roulette    onepoint  neighborBoard  1.00        8
# 139         roulette    onepoint  neighborBoard  1.00        9
# 140         roulette    onepoint  neighborBoard  0.50        0
# 141         roulette    onepoint  neighborBoard  0.50        1
# 142         roulette    onepoint  neighborBoard  0.50        2
# 143         roulette    onepoint  neighborBoard  0.50        3
# 144         roulette    onepoint  neighborBoard  0.50        4
# 145         roulette    onepoint  neighborBoard  0.50        5
# 146         roulette    onepoint  neighborBoard  0.50        6
# 147         roulette    onepoint  neighborBoard  0.50        7
# 148         roulette    onepoint  neighborBoard  0.50        8
# 149         roulette    onepoint  neighborBoard  0.50        9
# 150         roulette     uniform       position  0.00        0
# 151         roulette     uniform       position  0.00        1
# 152         roulette     uniform       position  0.00        2
# 153         roulette     uniform       position  0.00        3
# 154         roulette     uniform       position  0.00        4
# 155         roulette     uniform       position  0.00        5
# 156         roulette     uniform       position  0.00        6
# 157         roulette     uniform       position  0.00        7
# 158         roulette     uniform       position  0.00        8
# 159         roulette     uniform       position  0.00        9
# 160         roulette     uniform       position  0.25        0
# 161         roulette     uniform       position  0.25        1
# 162         roulette     uniform       position  0.25        2
# 163         roulette     uniform       position  0.25        3
# 164         roulette     uniform       position  0.25        4
# 165         roulette     uniform       position  0.25        5
# 166         roulette     uniform       position  0.25        6
# 167         roulette     uniform       position  0.25        7
# 168         roulette     uniform       position  0.25        8
# 169         roulette     uniform       position  0.25        9
# 170         roulette     uniform       position  0.75        0
# 171         roulette     uniform       position  0.75        1
# 172         roulette     uniform       position  0.75        2
# 173         roulette     uniform       position  0.75        3
# 174         roulette     uniform       position  0.75        4
# 175         roulette     uniform       position  0.75        5
# 176         roulette     uniform       position  0.75        6
# 177         roulette     uniform       position  0.75        7
# 178         roulette     uniform       position  0.75        8
# 179         roulette     uniform       position  0.75        9
# 180         roulette     uniform       position  1.00        0
# 181         roulette     uniform       position  1.00        1
# 182         roulette     uniform       position  1.00        2
# 183         roulette     uniform       position  1.00        3
# 184         roulette     uniform       position  1.00        4
# 185         roulette     uniform       position  1.00        5
# 186         roulette     uniform       position  1.00        6
# 187         roulette     uniform       position  1.00        7
# 188         roulette     uniform       position  1.00        8
# 189         roulette     uniform       position  1.00        9
# 190         roulette     uniform       position  0.50        0
# 191         roulette     uniform       position  0.50        1
# 192         roulette     uniform       position  0.50        2
# 193         roulette     uniform       position  0.50        3
# 194         roulette     uniform       position  0.50        4
# 195         roulette     uniform       position  0.50        5
# 196         roulette     uniform       position  0.50        6
# 197         roulette     uniform       position  0.50        7
# 198         roulette     uniform       position  0.50        8
# 199         roulette     uniform       position  0.50        9
# 200         roulette     uniform           swap  0.00        0
# 201         roulette     uniform           swap  0.00        1
# 202         roulette     uniform           swap  0.00        2
# 203         roulette     uniform           swap  0.00        3
# 204         roulette     uniform           swap  0.00        4
# 205         roulette     uniform           swap  0.00        5
# 206         roulette     uniform           swap  0.00        6
# 207         roulette     uniform           swap  0.00        7
# 208         roulette     uniform           swap  0.00        8
# 209         roulette     uniform           swap  0.00        9
# 210         roulette     uniform           swap  0.25        0
# 211         roulette     uniform           swap  0.25        1
# 212         roulette     uniform           swap  0.25        2
# 213         roulette     uniform           swap  0.25        3
# 214         roulette     uniform           swap  0.25        4
# 215         roulette     uniform           swap  0.25        5
# 216         roulette     uniform           swap  0.25        6
# 217         roulette     uniform           swap  0.25        7
# 218         roulette     uniform           swap  0.25        8
# 219         roulette     uniform           swap  0.25        9
# 220         roulette     uniform           swap  0.75        0
# 221         roulette     uniform           swap  0.75        1
# 222         roulette     uniform           swap  0.75        2
# 223         roulette     uniform           swap  0.75        3
# 224         roulette     uniform           swap  0.75        4
# 225         roulette     uniform           swap  0.75        5
# 226         roulette     uniform           swap  0.75        6
# 227         roulette     uniform           swap  0.75        7
# 228         roulette     uniform           swap  0.75        8
# 229         roulette     uniform           swap  0.75        9
# 230         roulette     uniform           swap  1.00        0
# 231         roulette     uniform           swap  1.00        1
# 232         roulette     uniform           swap  1.00        2
# 233         roulette     uniform           swap  1.00        3
# 234         roulette     uniform           swap  1.00        4
# 235         roulette     uniform           swap  1.00        5
# 236         roulette     uniform           swap  1.00        6
# 237         roulette     uniform           swap  1.00        7
# 238         roulette     uniform           swap  1.00        8
# 239         roulette     uniform           swap  1.00        9
# 240         roulette     uniform           swap  0.50        0
# 241         roulette     uniform           swap  0.50        1
# 242         roulette     uniform           swap  0.50        2
# 243         roulette     uniform           swap  0.50        3
# 244         roulette     uniform           swap  0.50        4
# 245         roulette     uniform           swap  0.50        5
# 246         roulette     uniform           swap  0.50        6
# 247         roulette     uniform           swap  0.50        7
# 248         roulette     uniform           swap  0.50        8
# 249         roulette     uniform           swap  0.50        9
# 250         roulette     uniform  neighborBoard  0.00        0
# 251         roulette     uniform  neighborBoard  0.00        1
# 252         roulette     uniform  neighborBoard  0.00        2
# 253         roulette     uniform  neighborBoard  0.00        3
# 254         roulette     uniform  neighborBoard  0.00        4
# 255         roulette     uniform  neighborBoard  0.00        5
# 256         roulette     uniform  neighborBoard  0.00        6
# 257         roulette     uniform  neighborBoard  0.00        7
# 258         roulette     uniform  neighborBoard  0.00        8
# 259         roulette     uniform  neighborBoard  0.00        9
# 260         roulette     uniform  neighborBoard  0.25        0
# 261         roulette     uniform  neighborBoard  0.25        1
# 262         roulette     uniform  neighborBoard  0.25        2
# 263         roulette     uniform  neighborBoard  0.25        3
# 264         roulette     uniform  neighborBoard  0.25        4
# 265         roulette     uniform  neighborBoard  0.25        5
# 266         roulette     uniform  neighborBoard  0.25        6
# 267         roulette     uniform  neighborBoard  0.25        7
# 268         roulette     uniform  neighborBoard  0.25        8
# 269         roulette     uniform  neighborBoard  0.25        9
# 270         roulette     uniform  neighborBoard  0.75        0
# 271         roulette     uniform  neighborBoard  0.75        1
# 272         roulette     uniform  neighborBoard  0.75        2
# 273         roulette     uniform  neighborBoard  0.75        3
# 274         roulette     uniform  neighborBoard  0.75        4
# 275         roulette     uniform  neighborBoard  0.75        5
# 276         roulette     uniform  neighborBoard  0.75        6
# 277         roulette     uniform  neighborBoard  0.75        7
# 278         roulette     uniform  neighborBoard  0.75        8
# 279         roulette     uniform  neighborBoard  0.75        9
# 280         roulette     uniform  neighborBoard  1.00        0
# 281         roulette     uniform  neighborBoard  1.00        1
# 282         roulette     uniform  neighborBoard  1.00        2
# 283         roulette     uniform  neighborBoard  1.00        3
# 284         roulette     uniform  neighborBoard  1.00        4
# 285         roulette     uniform  neighborBoard  1.00        5
# 286         roulette     uniform  neighborBoard  1.00        6
# 287         roulette     uniform  neighborBoard  1.00        7
# 288         roulette     uniform  neighborBoard  1.00        8
# 289         roulette     uniform  neighborBoard  1.00        9
# 290         roulette     uniform  neighborBoard  0.50        0
# 291         roulette     uniform  neighborBoard  0.50        1
# 292         roulette     uniform  neighborBoard  0.50        2
# 293         roulette     uniform  neighborBoard  0.50        3
# 294         roulette     uniform  neighborBoard  0.50        4
# 295         roulette     uniform  neighborBoard  0.50        5
# 296         roulette     uniform  neighborBoard  0.50        6
# 297         roulette     uniform  neighborBoard  0.50        7
# 298         roulette     uniform  neighborBoard  0.50        8
# 299         roulette     uniform  neighborBoard  0.50        9
# 300       tournament    onepoint       position  0.00        0
# 301       tournament    onepoint       position  0.00        1
# 302       tournament    onepoint       position  0.00        2
# 303       tournament    onepoint       position  0.00        3
# 304       tournament    onepoint       position  0.00        4
# 305       tournament    onepoint       position  0.00        5
# 306       tournament    onepoint       position  0.00        6
# 307       tournament    onepoint       position  0.00        7
# 308       tournament    onepoint       position  0.00        8
# 309       tournament    onepoint       position  0.00        9
# 310       tournament    onepoint       position  0.25        0
# 311       tournament    onepoint       position  0.25        1
# 312       tournament    onepoint       position  0.25        2
# 313       tournament    onepoint       position  0.25        3
# 314       tournament    onepoint       position  0.25        4
# 315       tournament    onepoint       position  0.25        5
# 316       tournament    onepoint       position  0.25        6
# 317       tournament    onepoint       position  0.25        7
# 318       tournament    onepoint       position  0.25        8
# 319       tournament    onepoint       position  0.25        9
# 320       tournament    onepoint       position  0.75        0
# 321       tournament    onepoint       position  0.75        1
# 322       tournament    onepoint       position  0.75        2
# 323       tournament    onepoint       position  0.75        3
# 324       tournament    onepoint       position  0.75        4
# 325       tournament    onepoint       position  0.75        5
# 326       tournament    onepoint       position  0.75        6
# 327       tournament    onepoint       position  0.75        7
# 328       tournament    onepoint       position  0.75        8
# 329       tournament    onepoint       position  0.75        9
# 330       tournament    onepoint       position  1.00        0
# 331       tournament    onepoint       position  1.00        1
# 332       tournament    onepoint       position  1.00        2
# 333       tournament    onepoint       position  1.00        3
# 334       tournament    onepoint       position  1.00        4
# 335       tournament    onepoint       position  1.00        5
# 336       tournament    onepoint       position  1.00        6
# 337       tournament    onepoint       position  1.00        7
# 338       tournament    onepoint       position  1.00        8
# 339       tournament    onepoint       position  1.00        9
# 340       tournament    onepoint       position  0.50        0
# 341       tournament    onepoint       position  0.50        1
# 342       tournament    onepoint       position  0.50        2
# 343       tournament    onepoint       position  0.50        3
# 344       tournament    onepoint       position  0.50        4
# 345       tournament    onepoint       position  0.50        5
# 346       tournament    onepoint       position  0.50        6
# 347       tournament    onepoint       position  0.50        7
# 348       tournament    onepoint       position  0.50        8
# 349       tournament    onepoint       position  0.50        9
# 350       tournament    onepoint           swap  0.00        0
# 351       tournament    onepoint           swap  0.00        1
# 352       tournament    onepoint           swap  0.00        2
# 353       tournament    onepoint           swap  0.00        3
# 354       tournament    onepoint           swap  0.00        4
# 355       tournament    onepoint           swap  0.00        5
# 356       tournament    onepoint           swap  0.00        6
# 357       tournament    onepoint           swap  0.00        7
# 358       tournament    onepoint           swap  0.00        8
# 359       tournament    onepoint           swap  0.00        9
# 360       tournament    onepoint           swap  0.25        0
# 361       tournament    onepoint           swap  0.25        1
# 362       tournament    onepoint           swap  0.25        2
# 363       tournament    onepoint           swap  0.25        3
# 364       tournament    onepoint           swap  0.25        4
# 365       tournament    onepoint           swap  0.25        5
# 366       tournament    onepoint           swap  0.25        6
# 367       tournament    onepoint           swap  0.25        7
# 368       tournament    onepoint           swap  0.25        8
# 369       tournament    onepoint           swap  0.25        9
# 370       tournament    onepoint           swap  0.75        0
# 371       tournament    onepoint           swap  0.75        1
# 372       tournament    onepoint           swap  0.75        2
# 373       tournament    onepoint           swap  0.75        3
# 374       tournament    onepoint           swap  0.75        4
# 375       tournament    onepoint           swap  0.75        5
# 376       tournament    onepoint           swap  0.75        6
# 377       tournament    onepoint           swap  0.75        7
# 378       tournament    onepoint           swap  0.75        8
# 379       tournament    onepoint           swap  0.75        9
# 380       tournament    onepoint           swap  1.00        0
# 381       tournament    onepoint           swap  1.00        1
# 382       tournament    onepoint           swap  1.00        2
# 383       tournament    onepoint           swap  1.00        3
# 384       tournament    onepoint           swap  1.00        4
# 385       tournament    onepoint           swap  1.00        5
# 386       tournament    onepoint           swap  1.00        6
# 387       tournament    onepoint           swap  1.00        7
# 388       tournament    onepoint           swap  1.00        8
# 389       tournament    onepoint           swap  1.00        9
# 390       tournament    onepoint           swap  0.50        0
# 391       tournament    onepoint           swap  0.50        1
# 392       tournament    onepoint           swap  0.50        2
# 393       tournament    onepoint           swap  0.50        3
# 394       tournament    onepoint           swap  0.50        4
# 395       tournament    onepoint           swap  0.50        5
# 396       tournament    onepoint           swap  0.50        6
# 397       tournament    onepoint           swap  0.50        7
# 398       tournament    onepoint           swap  0.50        8
# 399       tournament    onepoint           swap  0.50        9
# 400       tournament    onepoint  neighborBoard  0.00        0
# 401       tournament    onepoint  neighborBoard  0.00        1
# 402       tournament    onepoint  neighborBoard  0.00        2
# 403       tournament    onepoint  neighborBoard  0.00        3
# 404       tournament    onepoint  neighborBoard  0.00        4
# 405       tournament    onepoint  neighborBoard  0.00        5
# 406       tournament    onepoint  neighborBoard  0.00        6
# 407       tournament    onepoint  neighborBoard  0.00        7
# 408       tournament    onepoint  neighborBoard  0.00        8
# 409       tournament    onepoint  neighborBoard  0.00        9
# 410       tournament    onepoint  neighborBoard  0.25        0
# 411       tournament    onepoint  neighborBoard  0.25        1
# 412       tournament    onepoint  neighborBoard  0.25        2
# 413       tournament    onepoint  neighborBoard  0.25        3
# 414       tournament    onepoint  neighborBoard  0.25        4
# 415       tournament    onepoint  neighborBoard  0.25        5
# 416       tournament    onepoint  neighborBoard  0.25        6
# 417       tournament    onepoint  neighborBoard  0.25        7
# 418       tournament    onepoint  neighborBoard  0.25        8
# 419       tournament    onepoint  neighborBoard  0.25        9
# 420       tournament    onepoint  neighborBoard  0.75        0
# 421       tournament    onepoint  neighborBoard  0.75        1
# 422       tournament    onepoint  neighborBoard  0.75        2
# 423       tournament    onepoint  neighborBoard  0.75        3
# 424       tournament    onepoint  neighborBoard  0.75        4
# 425       tournament    onepoint  neighborBoard  0.75        5
# 426       tournament    onepoint  neighborBoard  0.75        6
# 427       tournament    onepoint  neighborBoard  0.75        7
# 428       tournament    onepoint  neighborBoard  0.75        8
# 429       tournament    onepoint  neighborBoard  0.75        9
# 430       tournament    onepoint  neighborBoard  1.00        0
# 431       tournament    onepoint  neighborBoard  1.00        1
# 432       tournament    onepoint  neighborBoard  1.00        2
# 433       tournament    onepoint  neighborBoard  1.00        3
# 434       tournament    onepoint  neighborBoard  1.00        4
# 435       tournament    onepoint  neighborBoard  1.00        5
# 436       tournament    onepoint  neighborBoard  1.00        6
# 437       tournament    onepoint  neighborBoard  1.00        7
# 438       tournament    onepoint  neighborBoard  1.00        8
# 439       tournament    onepoint  neighborBoard  1.00        9
# 440       tournament    onepoint  neighborBoard  0.50        0
# 441       tournament    onepoint  neighborBoard  0.50        1
# 442       tournament    onepoint  neighborBoard  0.50        2
# 443       tournament    onepoint  neighborBoard  0.50        3
# 444       tournament    onepoint  neighborBoard  0.50        4
# 445       tournament    onepoint  neighborBoard  0.50        5
# 446       tournament    onepoint  neighborBoard  0.50        6
# 447       tournament    onepoint  neighborBoard  0.50        7
# 448       tournament    onepoint  neighborBoard  0.50        8
# 449       tournament    onepoint  neighborBoard  0.50        9
# 450       tournament     uniform       position  0.00        0
# 451       tournament     uniform       position  0.00        1
# 452       tournament     uniform       position  0.00        2
# 453       tournament     uniform       position  0.00        3
# 454       tournament     uniform       position  0.00        4
# 455       tournament     uniform       position  0.00        5
# 456       tournament     uniform       position  0.00        6
# 457       tournament     uniform       position  0.00        7
# 458       tournament     uniform       position  0.00        8
# 459       tournament     uniform       position  0.00        9
# 460       tournament     uniform       position  0.25        0
# 461       tournament     uniform       position  0.25        1
# 462       tournament     uniform       position  0.25        2
# 463       tournament     uniform       position  0.25        3
# 464       tournament     uniform       position  0.25        4
# 465       tournament     uniform       position  0.25        5
# 466       tournament     uniform       position  0.25        6
# 467       tournament     uniform       position  0.25        7
# 468       tournament     uniform       position  0.25        8
# 469       tournament     uniform       position  0.25        9
# 470       tournament     uniform       position  0.75        0
# 471       tournament     uniform       position  0.75        1
# 472       tournament     uniform       position  0.75        2
# 473       tournament     uniform       position  0.75        3
# 474       tournament     uniform       position  0.75        4
# 475       tournament     uniform       position  0.75        5
# 476       tournament     uniform       position  0.75        6
# 477       tournament     uniform       position  0.75        7
# 478       tournament     uniform       position  0.75        8
# 479       tournament     uniform       position  0.75        9
# 480       tournament     uniform       position  1.00        0
# 481       tournament     uniform       position  1.00        1
# 482       tournament     uniform       position  1.00        2
# 483       tournament     uniform       position  1.00        3
# 484       tournament     uniform       position  1.00        4
# 485       tournament     uniform       position  1.00        5
# 486       tournament     uniform       position  1.00        6
# 487       tournament     uniform       position  1.00        7
# 488       tournament     uniform       position  1.00        8
# 489       tournament     uniform       position  1.00        9
# 490       tournament     uniform       position  0.50        0
# 491       tournament     uniform       position  0.50        1
# 492       tournament     uniform       position  0.50        2
# 493       tournament     uniform       position  0.50        3
# 494       tournament     uniform       position  0.50        4
# 495       tournament     uniform       position  0.50        5
# 496       tournament     uniform       position  0.50        6
# 497       tournament     uniform       position  0.50        7
# 498       tournament     uniform       position  0.50        8
# 499       tournament     uniform       position  0.50        9
# 500       tournament     uniform           swap  0.00        0
# 501       tournament     uniform           swap  0.00        1
# 502       tournament     uniform           swap  0.00        2
# 503       tournament     uniform           swap  0.00        3
# 504       tournament     uniform           swap  0.00        4
# 505       tournament     uniform           swap  0.00        5
# 506       tournament     uniform           swap  0.00        6
# 507       tournament     uniform           swap  0.00        7
# 508       tournament     uniform           swap  0.00        8
# 509       tournament     uniform           swap  0.00        9
# 510       tournament     uniform           swap  0.25        0
# 511       tournament     uniform           swap  0.25        1
# 512       tournament     uniform           swap  0.25        2
# 513       tournament     uniform           swap  0.25        3
# 514       tournament     uniform           swap  0.25        4
# 515       tournament     uniform           swap  0.25        5
# 516       tournament     uniform           swap  0.25        6
# 517       tournament     uniform           swap  0.25        7
# 518       tournament     uniform           swap  0.25        8
# 519       tournament     uniform           swap  0.25        9
# 520       tournament     uniform           swap  0.75        0
# 521       tournament     uniform           swap  0.75        1
# 522       tournament     uniform           swap  0.75        2
# 523       tournament     uniform           swap  0.75        3
# 524       tournament     uniform           swap  0.75        4
# 525       tournament     uniform           swap  0.75        5
# 526       tournament     uniform           swap  0.75        6
# 527       tournament     uniform           swap  0.75        7
# 528       tournament     uniform           swap  0.75        8
# 529       tournament     uniform           swap  0.75        9
# 530       tournament     uniform           swap  1.00        0
# 531       tournament     uniform           swap  1.00        1
# 532       tournament     uniform           swap  1.00        2
# 533       tournament     uniform           swap  1.00        3
# 534       tournament     uniform           swap  1.00        4
# 535       tournament     uniform           swap  1.00        5
# 536       tournament     uniform           swap  1.00        6
# 537       tournament     uniform           swap  1.00        7
# 538       tournament     uniform           swap  1.00        8
# 539       tournament     uniform           swap  1.00        9
# 540       tournament     uniform           swap  0.50        0
# 541       tournament     uniform           swap  0.50        1
# 542       tournament     uniform           swap  0.50        2
# 543       tournament     uniform           swap  0.50        3
# 544       tournament     uniform           swap  0.50        4
# 545       tournament     uniform           swap  0.50        5
# 546       tournament     uniform           swap  0.50        6
# 547       tournament     uniform           swap  0.50        7
# 548       tournament     uniform           swap  0.50        8
# 549       tournament     uniform           swap  0.50        9
# 550       tournament     uniform  neighborBoard  0.00        0
# 551       tournament     uniform  neighborBoard  0.00        1
# 552       tournament     uniform  neighborBoard  0.00        2
# 553       tournament     uniform  neighborBoard  0.00        3
# 554       tournament     uniform  neighborBoard  0.00        4
# 555       tournament     uniform  neighborBoard  0.00        5
# 556       tournament     uniform  neighborBoard  0.00        6
# 557       tournament     uniform  neighborBoard  0.00        7
# 558       tournament     uniform  neighborBoard  0.00        8
# 559       tournament     uniform  neighborBoard  0.00        9
# 560       tournament     uniform  neighborBoard  0.25        0
# 561       tournament     uniform  neighborBoard  0.25        1
# 562       tournament     uniform  neighborBoard  0.25        2
# 563       tournament     uniform  neighborBoard  0.25        3
# 564       tournament     uniform  neighborBoard  0.25        4
# 565       tournament     uniform  neighborBoard  0.25        5
# 566       tournament     uniform  neighborBoard  0.25        6
# 567       tournament     uniform  neighborBoard  0.25        7
# 568       tournament     uniform  neighborBoard  0.25        8
# 569       tournament     uniform  neighborBoard  0.25        9
# 570       tournament     uniform  neighborBoard  0.75        0
# 571       tournament     uniform  neighborBoard  0.75        1
# 572       tournament     uniform  neighborBoard  0.75        2
# 573       tournament     uniform  neighborBoard  0.75        3
# 574       tournament     uniform  neighborBoard  0.75        4
# 575       tournament     uniform  neighborBoard  0.75        5
# 576       tournament     uniform  neighborBoard  0.75        6
# 577       tournament     uniform  neighborBoard  0.75        7
# 578       tournament     uniform  neighborBoard  0.75        8
# 579       tournament     uniform  neighborBoard  0.75        9
# 580       tournament     uniform  neighborBoard  1.00        0
# 581       tournament     uniform  neighborBoard  1.00        1
# 582       tournament     uniform  neighborBoard  1.00        2
# 583       tournament     uniform  neighborBoard  1.00        3
# 584       tournament     uniform  neighborBoard  1.00        4
# 585       tournament     uniform  neighborBoard  1.00        5
# 586       tournament     uniform  neighborBoard  1.00        6
# 587       tournament     uniform  neighborBoard  1.00        7
# 588       tournament     uniform  neighborBoard  1.00        8
# 589       tournament     uniform  neighborBoard  1.00        9
# 590       tournament     uniform  neighborBoard  0.50        0
# 591       tournament     uniform  neighborBoard  0.50        1
# 592       tournament     uniform  neighborBoard  0.50        2
# 593       tournament     uniform  neighborBoard  0.50        3
# 594       tournament     uniform  neighborBoard  0.50        4
# 595       tournament     uniform  neighborBoard  0.50        5
# 596       tournament     uniform  neighborBoard  0.50        6
# 597       tournament     uniform  neighborBoard  0.50        7
# 598       tournament     uniform  neighborBoard  0.50        8
# 599       tournament     uniform  neighborBoard  0.50        9
#
#      Generacion_Convergencia  Maximo_fitness  \
# 0                          0             122
# 1                          0             122
# 2                         48             123
# 3                          0             122
# 4                          0             122
# 5                         34             126
# 6                          0             122
# 7                          0             122
# 8                          0             122
# 9                          0             122
# 10                       369             145
# 11                       411             146
# 12                       706             147
# 13                       494             145
# 14                       200             142
# 15                       423             153
# 16                       570             145
# 17                       533             145
# 18                       844             149
# 19                       889             148
# 20                       613             151
# 21                       122             143
# 22                       252             147
# 23                       528             149
# 24                       178             144
# 25                       139             146
# 26                       285             149
# 27                       474             148
# 28                       245             146
# 29                       428             153
# 30                       299             149
# 31                       204             150
# 32                       673             151
# 33                       206             146
# 34                       468             154
# 35                       455             151
# 36                       760             150
# 37                       486             151
# 38                       495             150
# 39                       177             149
# 40                       291             146
# 41                       948             146
# 42                       396             146
# 43                       479             145
# 44                       603             149
# 45                       563             147
# 46                       799             146
# 47                       195             144
# 48                       671             147
# 49                       167             147
# 50                         0             122
# 51                       201             124
# 52                         0             122
# 53                         0             122
# 54                         0             122
# 55                         0             122
# 56                        11             123
# 57                         0             122
# 58                         0             122
# 59                         0             122
# 60                       707             147
# 61                       825             152
# 62                       804             150
# 63                       883             152
# 64                       944             143
# 65                       446             147
# 66                       958             149
# 67                       767             147
# 68                       414             144
# 69                       774             150
# 70                       738             147
# 71                       799             148
# 72                       358             154
# 73                       641             153
# 74                       449             152
# 75                       762             154
# 76                       709             151
# 77                       917             154
# 78                       867             153
# 79                       366             154
# 80                       800             160
# 81                       910             155
# 82                       800             153
# 83                       549             154
# 84                       590             152
# 85                       569             151
# 86                       341             151
# 87                       375             156
# 88                       934             155
# 89                       673             155
# 90                       526             152
# 91                       375             150
# 92                       835             154
# 93                       591             150
# 94                       199             148
# 95                       582             152
# 96                       339             152
# 97                       823             147
# 98                       926             153
# 99                       595             150
# 100                       11             123
# 101                        0             122
# 102                        0             122
# 103                        0             122
# 104                       69             123
# 105                        0             122
# 106                        0             122
# 107                        0             122
# 108                        0             122
# 109                        0             122
# 110                        0             122
# 111                        0             122
# 112                       60             123
# 113                        0             122
# 114                        0             122
# 115                        0             122
# 116                       28             123
# 117                       68             124
# 118                        0             122
# 119                        0             122
# 120                        0             122
# 121                        0             122
# 122                       20             125
# 123                        0             122
# 124                       15             125
# 125                        0             122
# 126                       15             123
# 127                       53             123
# 128                      164             123
# 129                        0             122
# 130                       23             125
# 131                       25             123
# 132                        0             122
# 133                        0             122
# 134                        0             122
# 135                        0             122
# 136                        0             122
# 137                        0             122
# 138                        0             122
# 139                        0             122
# 140                        0             122
# 141                       16             123
# 142                        0             122
# 143                        0             122
# 144                        0             122
# 145                        0             122
# 146                        0             122
# 147                        0             122
# 148                        0             122
# 149                       20             123
# 150                       28             133
# 151                       17             132
# 152                      812             127
# 153                       32             134
# 154                       36             132
# 155                       33             134
# 156                       19             128
# 157                       33             128
# 158                       25             128
# 159                       23             129
# 160                      456             148
# 161                      525             141
# 162                      662             144
# 163                      406             148
# 164                      717             149
# 165                      893             150
# 166                      660             149
# 167                      715             144
# 168                      765             149
# 169                      777             147
# 170                      281             152
# 171                      298             153
# ...
# 320  [2, 5, 4, 1, 8, 7, 7, 6, 3, 2, 3, 8, 7, 1, 4, ...
# 321  [2, 8, 6, 1, 7, 4, 5, 3, 4, 7, 1, 3, 5, 6, 2, ...
# 322  [2, 7, 9, 3, 8, 1, 5, 6, 4, 1, 9, 5, 2, 3, 7, ...
# 323  [2, 5, 1, 3, 7, 4, 8, 6, 9, 4, 3, 8, 6, 4, 2, ...
# 324  [2, 3, 1, 5, 7, 4, 6, 6, 8, 1, 4, 8, 6, 3, 2, ...
# 325  [2, 8, 1, 6, 2, 4, 9, 7, 3, 4, 6, 8, 5, 8, 3, ...
# 326  [2, 8, 3, 7, 6, 4, 6, 5, 1, 9, 1, 4, 6, 8, 2, ...
# 327  [2, 8, 5, 1, 7, 4, 6, 3, 4, 1, 6, 8, 3, 5, 2, ...
# 328  [2, 8, 1, 6, 5, 7, 2, 3, 4, 2, 3, 8, 8, 7, 4, ...
# 329  [2, 8, 1, 1, 7, 4, 6, 5, 3, 7, 4, 8, 6, 8, 2, ...
# 330  [2, 8, 6, 1, 7, 4, 5, 8, 3, 4, 4, 2, 6, 8, 1, ...
# 331  [6, 5, 3, 2, 4, 8, 2, 1, 7, 7, 2, 5, 9, 3, 1, ...
# 332  [2, 8, 1, 1, 7, 4, 3, 6, 5, 4, 6, 8, 6, 2, 9, ...
# 333  [6, 1, 4, 3, 2, 8, 5, 7, 9, 2, 3, 4, 6, 8, 1, ...
# 334  [9, 4, 9, 7, 5, 8, 6, 2, 3, 2, 3, 8, 1, 7, 4, ...
# 335  [2, 8, 5, 1, 3, 4, 6, 7, 2, 4, 5, 1, 6, 8, 2, ...
# 336  [2, 8, 1, 3, 7, 4, 6, 4, 5, 7, 6, 5, 9, 1, 2, ...
# 337  [2, 8, 1, 3, 3, 4, 6, 6, 5, 5, 6, 2, 4, 8, 9, ...
 4, 4, 4, 6, 8, 6, 8, 3, ...
# 574  [2, 8, 1, 1, 7, 4, 2, 4, 4, 5, 6, 8, 6, 8, 2, ...
# 575  [9, 8, 1, 5, 3, 4, 8, 4, 4, 5, 6, 8, 6, 8, 9, ...
# 576  [2, 1, 3, 6, 1, 4, 7, 2, 9, 7, 6, 3, 9, 3, 2, ...
# 577  [9, 8, 1, 6, 7, 8, 2, 4, 4, 2, 6, 8, 6, 8, 3, ...
# 578  [2, 8, 9, 6, 7, 4, 2, 4, 6, 4, 3, 8, 6, 7, 5, ...
# 579  [2, 1, 3, 6, 1, 4, 8, 4, 9, 7, 6, 3, 2, 3, 9, ...
# 580  [2, 8, 1, 1, 7, 4, 2, 4, 4, 4, 6, 8, 6, 8, 3, ...
# 581  [4, 5, 9, 1, 7, 8, 6, 4, 4, 2, 6, 1, 8, 8, 3, ...
# 582  [9, 8, 3, 1, 1, 4, 2, 4, 9, 2, 6, 5, 8, 8, 9, ...
# 583  [2, 1, 3, 6, 1, 4, 2, 4, 9, 7, 3, 3, 9, 3, 3, ...
# 584  [2, 8, 1, 6, 7, 4, 9, 2, 4, 7, 6, 5, 8, 8, 2, ...
# 585  [2, 8, 1, 1, 7, 4, 6, 4, 4, 4, 6, 8, 6, 8, 2, ...
# 586  [2, 8, 1, 1, 7, 4, 8, 4, 4, 2, 6, 8, 8, 8, 4, ...
# 587  [2, 8, 1, 6, 7, 4, 9, 3, 4, 5, 7, 1, 6, 8, 2, ...
# 588  [9, 8, 1, 6, 7, 4, 9, 2, 4, 4, 6, 8, 8, 8, 9, ...
# 589  [2, 8, 3, 1, 1, 4, 9, 4, 9, 4, 6, 8, 2, 7, 9, ...
# 590  [2, 5, 1, 1, 7, 8, 6, 4, 4, 7, 6, 8, 1, 8, 2, ...
# 591  [2, 8, 1, 1, 6, 4, 9, 4, 4, 9, 6, 8, 6, 8, 9, ...
# 592  [2, 8, 1, 1, 7, 4, 7, 4, 4, 4, 7, 8, 6, 8, 3, ...
# 593  [2, 8, 1, 1, 7, 4, 6, 4, 4, 5, 6, 8, 6, 8, 9, ...
# 594  [2, 8, 1, 1, 7, 4, 6, 4, 4, 9, 6, 8, 6, 8, 3, ...
# 595  [2, 8, 1, 1, 7, 4, 8, 4, 4, 4, 6, 8, 6, 8, 9, ...
# 596  [2, 9, 1, 1, 7, 8, 3, 4, 6, 5, 1, 8, 6, 8, 3, ...
# 597  [2, 8, 1, 1, 7, 9, 3, 4, 4, 5, 6, 8, 6, 8, 9, ...
# 598  [9, 8, 1, 1, 7, 4, 9, 2, 4, 2, 6, 8, 6, 8, 4, ...
# 599  [9, 8, 9, 1, 6, 8, 8, 2, 4, 2, 6, 5, 6, 8, 4, ...

# %%
resultados.iloc[resultados["Maximo_fitness"].idxmax()]
# Out:
# Metodo Seleccion                                                    roulette
# Cruzamiento                                                         onepoint
# Mutacion                                                                swap
# Pm                                                                       1.0
# Corrida                                                                    0
# Generacion_Convergencia                                                  800
# Maximo_fitness                                                           160
# Cromosoma                  [2, 5, 6, 7, 3, 9, 8, 4, 1, 4, 7, 2, 6, 8, 9, ...
# Name: 80, dtype: object

# %%
# Se busca el cromosoma que tubo el maximo fitnes
mejor_cromosoma=resultados.iloc[resultados["Maximo_fitness"].idxmax()]['Cromosoma']
# Grafica del tablero de soduko con la mejor solucion
showBoard(mejor_cromosoma)
# Out:
# -------------------------
# | 2 5 6 | 7 3 9 | 8 4 1 |
# | 4 7 2 | 6 8 9 | 3 1 5 |
# | 6 9 4 | 8 5 1 | 7 3 2 |
# -------------------------
# | 5 4 7 | 2 9 3 | 1 8 6 |
# | 8 3 1 | 9 6 4 | 2 5 7 |
# | 7 8 5 | 3 1 2 | 4 9 9 |
# -------------------------
# | 9 1 8 | 4 2 7 | 5 6 3 |
# | 1 6 3 | 5 7 8 | 9 2 4 |
# | 3 2 9 | 1 4 5 | 6 7 8 |
# -------------------------

# %%
tabla_resumen=pd.DataFrame(resultados.groupby(['Metodo Seleccion','Cruzamiento','Mutacion','Pm'])[['Generacion_Convergencia','Maximo_fitness']].mean())
tabla_resumen.to_csv('tabla_resumen_fitness.csv')
tabla_resumen
# Out:
#                                                  Generacion_Convergencia  \
# Metodo Seleccion Cruzamiento Mutacion      Pm
# roulette         onepoint    neighborBoard 0.00                      8.0
#                                            0.25                     15.6
#                                            0.50                      3.6
#                                            0.75                     26.7
#                                            1.00                      4.8
#                              position      0.00                      8.2
#                                            0.25                    543.9
#                                            0.50                    511.2
#                                            0.75                    326.4
#                                            1.00                    422.3
#                              swap          0.00                     21.2
#                                            0.25                    752.2
#                                            0.50                    579.1
#                                            0.75                    660.6
#                                            1.00                    654.1
#                  uniform     neighborBoard 0.00                     25.1
#                                            0.25                     25.7
#                                            0.50                     30.3
#                                            0.75                     22.1
#                                            1.00                     23.1
#                              position      0.00                    105.8
#                                            0.25                    657.6
#                                            0.50                    384.2
#                                            0.75                    286.7
#                                            1.00                    564.4
#                              swap          0.00                     21.9
#                                            0.25                    794.2
#                                            0.50                    788.3
#                                            0.75                    711.7
#                                            1.00                    658.9
# tournament       onepoint    neighborBoard 0.00                      0.0
#                                            0.25                      0.0
#                                            0.50                     10.3
#                                            0.75                      0.7
#                                            1.00                     20.5
#                              position      0.00                      5.4
#                                            0.25                    602.8
#                                            0.50                    396.3
#                                            0.75                    278.3
#                                            1.00                    408.3
#                              swap          0.00                      2.4
#                                            0.25                    724.3
#                                            0.50                    774.7
#                                            0.75                    707.9
#                                            1.00                    604.2
#                  uniform     neighborBoard 0.00                     11.4
#                                            0.25                     10.9
#                                            0.50                     24.7
#                                            0.75                     36.0
#                                            1.00                     11.1
#                              position      0.00                     22.2
#                                            0.25                    655.1
#                                            0.50                    397.7
#                                            0.75                    323.6
#                                            1.00                    266.1
#                              swap          0.00                     10.6
#                                            0.25                    720.6
#                                            0.50                    728.9
#                                            0.75                    508.1
#                                            1.00                    533.3
#
#                                                  Maximo_fitness
# Metodo Seleccion Cruzamiento Mutacion      Pm
# roulette         onepoint    neighborBoard 0.00           122.2
#                                            0.25           122.4
#                                            0.50           122.2
#                                            0.75           122.9
#                                            1.00           122.4
#                              position      0.00           122.5
#                                            0.25           146.5
#                                            0.50           146.3
#                                            0.75           147.6
#                                            1.00           150.1
#                              swap          0.00           122.3
#                                            0.25           148.1
#                                            0.50           150.8
#                                            0.75           152.0
#                                            1.00           154.2
#                  uniform     neighborBoard 0.00           129.8
#                                            0.25           129.7
#                                            0.50           129.2
#                                            0.75           128.3
#                                            1.00           128.7
#                              position      0.00           130.5
#                                            0.25           146.9
#                                            0.50           148.6
#                                            0.75           149.3
#                                            1.00           151.1
#                              swap          0.00           127.8
#                                            0.25           148.9
#                                            0.50           152.4
#                                            0.75           153.9
#                                            1.00           155.2
# tournament       onepoint    neighborBoard 0.00           122.0
#                                            0.25           122.0
#                                            0.50           122.1
#                                            0.75           122.1
#                                            1.00           122.4
#                              position      0.00           122.1
#                                            0.25           147.0
#                                            0.50           147.1
#                                            0.75           147.4
#                                            1.00           149.2
#                              swap          0.00           122.2
#                                            0.25           148.1
#                                            0.50           149.5
#                                            0.75           152.9
#                                            1.00           154.1
#                  uniform     neighborBoard 0.00           124.6
#                                            0.25           125.6
#                                            0.50           124.1
#                                            0.75           125.6
#                                            1.00           126.6
#                              position      0.00           125.3
#                                            0.25           147.1
#                                            0.50           146.2
#                                            0.75           148.0
#                                            1.00           149.3
#                              swap          0.00           124.0
#                                            0.25           148.2
#                                            0.50           150.9
#                                            0.75           151.7
#                                            1.00           155.3

# %%
def init_population_ruta(lista):
    population = []
    for i in lista:
        new_chromosome = readBoardFromFile(i)
        population.append(Individual(new_chromosome))
    return population

# %%
# Inicializa una poblacion inicial de una ruta o lista de archivos
lista=['/content/puzzleA.txt','/content/puzzleB.txt','/content/puzzleC.txt','/content/puzzleD.txt','/content/puzzleE.txt']
poblacion_inicial = init_population_ruta(lista)

# %%
import matplotlib.pyplot as plt
ngen = 10000 # Nro de generaciones
pmut = 1 # taza de mutación
fitness_fn=fitness_soduko

metodoSeleccion=['roulette','tournament']
tournament_size = 3 #tamaño del torneo = 3

crossover=['onepoint','uniform']
mutation=['position','swap','neighborBoard']

lst_bestcrom=[]
best_ind, bestfitness,best_chromosoma = genetic_algorithm(poblacion_inicial, fitness_fn, ngen, pmut, tournament_size, 
                                          crossover[1], mutation[1], metodoSeleccion[0])
lst_bestcrom.append(best_ind)
plt.plot(bestfitness)
plt.show()
print("* Merjor Resultado *")
print("Generacion : {} , max de fitness: {} ,  Cromosoma: {} \n".format(bestfitness.index(max(bestfitness)),np.max(bestfitness),best_chromosoma))

# %%
# Grafica del tablero de soduko con la mejor solucion
showBoard(best_chromosoma)
# Out:
# -------------------------
# | 6 3 1 | 4 1 5 | 2 8 7 |
# | 2 4 9 | 1 3 7 | 5 6 8 |
# | 1 5 3 | 7 8 4 | 9 2 6 |
# -------------------------
# | 5 9 5 | 3 6 8 | 1 4 2 |
# | 4 6 7 | 8 9 2 | 3 1 5 |
# | 7 8 2 | 1 4 5 | 6 9 3 |
# -------------------------
# | 3 2 6 | 5 4 1 | 8 7 9 |
# | 8 1 4 | 9 5 6 | 7 3 4 |
# | 9 7 8 | 6 2 3 | 4 5 1 |
# -------------------------
